# %% [markdown]
# # Shift Cipher

# %% [markdown]
# * Alumna: Hernández García Nely

# %%
#Libraries
import pandas as pd
import numpy as np

# %%
#Dictionary
def dictionary():
    x=65;
    bandera=0;
    d=[]
    for i in range(61):
        if (i<26):
            d.append(x)
            x+=1
        if(i>=26 and i<52 and bandera==0):
            x=97
            bandera=1;
        if(i>=26 and i<52):
            d.append(x)
            x+=1
        if(i==52):
            d.append(34)
        if(i==53):
            d.append(40)
        if(i==54):
            d.append(41)
        if(i==55):
            d.append(63)
        if(i==56):
            d.append(39)
        if(i==57):
            d.append(58)
        if(i==58):
            d.append(59)
        if(i==59):
            d.append(44)
        if(i==60):
            d.append(46)
    return d

# %%
#Encrypt
def encrypt(text, k):
    result = ""
    d=dictionary()
    for i in range(len(text)):
        char = text[i]
        if(ord(char)!=32):
            m = d.index(ord(char))
            n = (m+k) % 61
            e = d[n]
            result += chr(e)
    return result

# %%
#Storing the data
mytext = "Classical Cryptography: Hidden Writing Consider two parties, Alice and Bob. Alice wants to privately send messages (called plaintexts) to Bob over an insecure channel. By an insecure channel, we here refer to an \"open\" and tappable channel; in particular, Alice and Bob would like their privacy to be maintained even in face of an adversary Eve (for eavesdropper) who listens to all messages sent on the channel. How can this be achieved? A possible solution Before starting their communication, Alice and Bob agree on some \"secret code\" that they will later use to communicate. A secret code consists of a key, an algorithm, Enc, to encrypt (scramble) plaintext messages into ciphertexts and an algorithm Dec to decrypt (or descramble) ciphertexts into plaintext messages. Both the encryption and decryption algorithms require the key to perform their task. Alice can now use the key to encrypt a message, and the send the ciphertext to Bob. Bob, upon receiving a ciphertext, uses the key to decrypt the ciphertext and retrieve the orignal message. First, a key k must be generated by the Gen algorithm and privately given to Alice and Bob. Later, Alice encodes the message m into a ciphertext c and sends it over the insecure channel, like over the airwaves. Bob receives the encoded message and decodes it using the key k to recover the original message m. The eavesdropper Eve does not learn anything about m except perhaps its length."
key = 16
print ("Texto: " + mytext)
# Out:
# Texto: Classical Cryptography: Hidden Writing Consider two parties, Alice and Bob. Alice wants to privately send messages (called plaintexts) to Bob over an insecure channel. By an insecure channel, we here refer to an "open" and tappable channel; in particular, Alice and Bob would like their privacy to be maintained even in face of an adversary Eve (for eavesdropper) who listens to all messages sent on the channel. How can this be achieved? A possible solution Before starting their communication, Alice and Bob agree on some "secret code" that they will later use to communicate. A secret code consists of a key, an algorithm, Enc, to encrypt (scramble) plaintext messages into ciphertexts and an algorithm Dec to decrypt (or descramble) ciphertexts into plaintext messages. Both the encryption and decryption algorithms require the key to perform their task. Alice can now use the key to encrypt a message, and the send the ciphertext to Bob. Bob, upon receiving a ciphertext, uses the key to decrypt the ciphertext and retrieve the orignal message. First, a key k must be generated by the Gen algorithm and privately given to Alice and Bob. Later, Alice encodes the message m into a ciphertext c and sends it over the insecure channel, like over the airwaves. Bob receives the encoded message and decodes it using the key k to recover the original message m. The eavesdropper Eve does not learn anything about m except perhaps its length.

# %%
#Key
print ("Key: " + str(key))
# Out:
# Key: 16

# %%
#Encoded
print ("Encoded: " + encrypt(mytext, key))
# Out:
# Encoded: S(q..ysq(S,F:A'w,q:xFMXyttu?m,yAy?wS'?.ytu,AD':q,Ayu.OQ(ysuq?tR'rPQ(ysuDq?A.A':,yCqAu(F.u?t)u..qwu.Isq((ut:(qy?AuEA.JA'R'r'Cu,q?y?.usB,usxq??u(PRFq?y?.usB,usxq??u(ODuxu,u,uvu,A'q?H':u?Hq?tAq::qr(usxq??u(Ny?:q,AysB(q,OQ(ysuq?tR'rD'B(t(y"uAxuy,:,yCqsFA'ru)qy?Aqy?utuCu?y?vqsu'vq?qtCu,.q,FUCuIv',uqCu.t,'::u,JDx'(y.Au?.A'q(()u..qwu..u?A'?Axusxq??u(PX'Dsq?Axy.ruqsxyuCutKQ:'..yr(u.'(BAy'?Ruv',u.Aq,Ay?wAxuy,s'))B?ysqAy'?OQ(ysuq?tR'rqw,uu'?.')uH.us,uAs'tuHAxqAAxuFDy(((qAu,B.uA's'))B?ysqAuPQ.us,uAs'tus'?.y.A.'vq"uFOq?q(w',yAx)OU?sOA'u?s,F:AI.s,q)r(uJ:(qy?AuEA)u..qwu.y?A'sy:xu,AuEA.q?tq?q(w',yAx)TusA'tus,F:AI',tu.s,q)r(uJsy:xu,AuEA.y?A':(qy?AuEA)u..qwu.PR'AxAxuu?s,F:Ay'?q?ttus,F:Ay'?q(w',yAx).,u;By,uAxu"uFA':u,v',)Axuy,Aq."PQ(ysusq??'DB.uAxu"uFA'u?s,F:Aq)u..qwuOq?tAxu.u?tAxusy:xu,AuEAA'R'rPR'rOB:'?,usuyCy?wqsy:xu,AuEAOB.u.Axu"uFA'tus,F:AAxusy:xu,AuEAq?t,uA,yuCuAxu',yw?q()u..qwuPVy,.AOq"uF")B.Aruwu?u,qAutrFAxuWu?q(w',yAx)q?t:,yCqAu(FwyCu?A'Q(ysuq?tR'rPbqAu,OQ(ysuu?s'tu.Axu)u..qwu)y?A'qsy:xu,AuEAsq?t.u?t.yA'Cu,Axuy?.usB,usxq??u(O(y"u'Cu,Axuqy,DqCu.PR'r,usuyCu.Axuu?s'tut)u..qwuq?ttus'tu.yAB.y?wAxu"uF"A',us'Cu,Axu',ywy?q()u..qwu)PjxuuqCu.t,'::u,UCut'u.?'A(uq,?q?FAxy?wqr'BA)uEsu:A:u,xq:.yA.(u?wAxP
