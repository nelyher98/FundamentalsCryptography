# %% [markdown]
# # Permutation Cipher

# %% [markdown]
# * Alumna: Hernández García Nely

# %%
#Libraries
import pandas as pd
import numpy as np  
import random

# %%
#Permutation
def permutation(m):
    lista = []
    numeros = []
    p = []
    for i in range(m):
        numeros.append(i)
    i=0
    while i<m:
        a=random.choice(list(numeros))
        if(a not in lista):
            lista.append(a)
            i+=1
    for i in range(m):
        b=lista.index(i)
        p.append(b)
    return lista, p

# %%
#Encrypt function
def encrypt(text, m):
    result = ""
    laux = []
    p,pi=permutation(m)
    print ("Permutación: "+str(p))
    print ()
    print ("Permutación inversa: "+str(pi))
    print ()
    j = 0
    for i in range (len(text)):
        char = text[i]
        if(ord(char)!=32 and j<m):
            laux.append(char)
            j += 1
        if(j==m):
            j = 0
            while j<m:
                result += laux[pi[j]]
                j += 1
            j = 0
            laux = []
    return result

# %%
#Storing the text
mytext = "Classical Cryptography: Hidden Writing Consider two parties, Alice and Bob. Alice wants to privately send messages (called plaintexts) to Bob over an insecure channel. By an insecure channel, we here refer to an \"open\" and tappable channel; in particular, Alice and Bob would like their privacy to be maintained even in face of an adversary Eve (for eavesdropper) who listens to all messages sent on the channel. How can this be achieved? A possible solution Before starting their communication, Alice and Bob agree on some \"secret code\" that they will later use to communicate. A secret code consists of a key, an algorithm, Enc, to encrypt (scramble) plaintext messages into ciphertexts and an algorithm Dec to decrypt (or descramble) ciphertexts into plaintext messages. Both the encryption and decryption algorithms require the key to perform their task. Alice can now use the key to encrypt a message, and the send the ciphertext to Bob. Bob, upon receiving a ciphertext, uses the key to decrypt the ciphertext and retrieve the orignal message. First, a key k must be generated by the Gen algorithm and privately given to Alice and Bob. Later, Alice encodes the message m into a ciphertext c and sends it over the insecure channel, like over the airwaves. Bob receives the encoded message and decodes it using the key k to recover the original message m. The eavesdropper Eve does not learn anything about m except perhaps its length."
parts = 602
print ("Text: " + mytext)
# Out:
# Text: Classical Cryptography: Hidden Writing Consider two parties, Alice and Bob. Alice wants to privately send messages (called plaintexts) to Bob over an insecure channel. By an insecure channel, we here refer to an "open" and tappable channel; in particular, Alice and Bob would like their privacy to be maintained even in face of an adversary Eve (for eavesdropper) who listens to all messages sent on the channel. How can this be achieved? A possible solution Before starting their communication, Alice and Bob agree on some "secret code" that they will later use to communicate. A secret code consists of a key, an algorithm, Enc, to encrypt (scramble) plaintext messages into ciphertexts and an algorithm Dec to decrypt (or descramble) ciphertexts into plaintext messages. Both the encryption and decryption algorithms require the key to perform their task. Alice can now use the key to encrypt a message, and the send the ciphertext to Bob. Bob, upon receiving a ciphertext, uses the key to decrypt the ciphertext and retrieve the orignal message. First, a key k must be generated by the Gen algorithm and privately given to Alice and Bob. Later, Alice encodes the message m into a ciphertext c and sends it over the insecure channel, like over the airwaves. Bob receives the encoded message and decodes it using the key k to recover the original message m. The eavesdropper Eve does not learn anything about m except perhaps its length.

